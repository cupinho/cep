# %%
import pandas as pd
import googlemaps as gm
import requests

# %%
dados = pd.read_csv('Imoveis_sem_cep_felix.csv', sep =';')
dados
# Out:
#      Id                        Endereco      Numero                  Bairro  \
# 0    38                   AV. ITABERABA        4827  VILA NOVA CACHOEIRINHA
# 1    42      RUA ARI CARNEIRO FERNANDES         263      Jardim dos Francos
# 2    48               RUA Tiro ao Pombo         402          Freguesia do O
# 3    79      RUA VINTE E DOIS DE AGOSTO         505       JARDIM BELA VISTA
# 4   327              RUA CIRILO CORREIA  168 CASA 0        JARDIM DAMASCENO
# 5   328              RUA CIRILO CORREIA  168 CASA 0        JARDIM DAMASCENO
# 6   201               RUA SANTO ADRIANO         240            PEDRA BRANCA
# 7   279                RUA FIRMINOPOLIS        1260        JD. VISTA ALEGRE
# 8   283             RUA CAPITAO FIRMINO          10                 LAUZANE
# 9   284              RUA ANTONIO AMORIM         126             Jardim Peri
# 10  288                      RUA ALMADA          33                  IMIRIM
# 11  290                     RUA AUGUSTA         746              Consolacao
# 12  323                           RUA B         187             Brasilandia
# 13  325        RUA BALTAZAR DA SILVEIRA        50a             VILA BONILHA
# 14  348    AV. Parada Pinto  207 Ap 505         505      V. N. Cachoeirinha
# 15  350  AV. Parada Pinto  207 - Ap 603         603      V; N. Cachoeirinha
# 16  352             RUA Vicente Lazzari         281             Brasilandia
# 17  361              RUA Jose Pedreschi         290      V. N. Cachoeirinha
# 18  386              RUA JOSE PEDRESCHI         290              VILA SOUZA
# 19  396              AV. PERI RONCHETTI         175             JARDIM PERI
# 20  397        RUA MAL.MELLO ARARIGBOIA         377              VILA SOUZA
# 21  398    RUA AUGUSTO VIANA DE CASTELO         216                  IMIRIM
# 22  401                   RUA JUAN ARFE          31          FREGUESIA DO O
# 23  403               RUA DOS MADRIGAIS          89        V.N.CACHOEIRINHA
# 24  406            AV. AV. PARADA PINTO        1345  VILA NOVA CACHOEIRINHA
# 25  579                     RUA Liestal          60        Lauzane Paulista
# 26  308          RUA DR.SALES MALHEIROS          42             JARDIM PERI
# 27  310       RUA MINISTRO BARBOSA LIMA          35       JARDIM  CACHOEIRA
# 28  320       RUA CACHOEIRA DOS ANTUNES          55             Jardim Peri
# 29  321        AV. General Penha Brasil   920 Altos      V. N. Cachoeirinha
# 30  295       RUA SANTO ANTONIO PLATINA         178                   Limao
#
#     Descricao
# 0   São Paulo
# 1   São Paulo
# 2   São Paulo
# 3   São Paulo
# 4   São Paulo
# 5   São Paulo
# 6   São Paulo
# 7   São Paulo
# 8   São Paulo
# 9   São Paulo
# 10  São Paulo
# 11  São Paulo
# 12  São Paulo
# 13  São Paulo
# 14  São Paulo
# 15  São Paulo
# 16  São Paulo
# 17  São Paulo
# 18  São Paulo
# 19  São Paulo
# 20  São Paulo
# 21  São Paulo
# 22  São Paulo
# 23  São Paulo
# 24  São Paulo
# 25  São Paulo
# 26  São Paulo
# 27  São Paulo
# 28  São Paulo
# 29        NaN
# 30        NaN

# %%
dados['Endereco1'] = dados['Endereco'] + ', '+ dados['Numero'] + ', ' + dados['Bairro'] + ', ' + dados['Descricao']
dados
# Out:
#      Id                        Endereco      Numero                  Bairro  \
# 0    38                   AV. ITABERABA        4827  VILA NOVA CACHOEIRINHA
# 1    42      RUA ARI CARNEIRO FERNANDES         263      Jardim dos Francos
# 2    48               RUA Tiro ao Pombo         402          Freguesia do O
# 3    79      RUA VINTE E DOIS DE AGOSTO         505       JARDIM BELA VISTA
# 18  São Paulo     RUA JOSE PEDRESCHI, 290, VILA SOUZA, São Paulo
# 19  São Paulo    AV. PERI RONCHETTI, 175, JARDIM PERI, São Paulo
# 20  São Paulo  RUA MAL.MELLO ARARIGBOIA, 377, VILA SOUZA, São...
# 21  São Paulo  RUA AUGUSTO VIANA DE CASTELO, 216, IMIRIM, São...
# 22  São Paulo       RUA JUAN ARFE, 31, FREGUESIA DO O, São Paulo
# 23  São Paulo  RUA DOS MADRIGAIS, 89, V.N.CACHOEIRINHA, São P...
# 24  São Paulo  AV. AV. PARADA PINTO, 1345, VILA NOVA CACHOEIR...
# 25  São Paulo       RUA Liestal, 60, Lauzane Paulista, São Paulo
# 26  São Paulo  RUA DR.SALES MALHEIROS, 42, JARDIM PERI, São P...
# 27  São Paulo  RUA MINISTRO BARBOSA LIMA, 35, JARDIM  CACHOEI...
# 28  São Paulo  RUA CACHOEIRA DOS ANTUNES, 55, Jardim Peri, Sã...
# 29        NaN                                                NaN
# 30        NaN                                                NaN

# %%
dados.Endereco1.fillna('erro', inplace = True)

# %%
API_KEY = 'AIzaSyARuS0UXjtWXThUyKL9KWfrFqVT7TDsmSI'
address1 = list(dados['Endereco1'])
address1
# Out:
# ['AV. ITABERABA, 4827, VILA NOVA CACHOEIRINHA, São Paulo',
#  'RUA ARI CARNEIRO FERNANDES, 263, Jardim dos Francos, São Paulo',
#  'RUA Tiro ao Pombo, 402, Freguesia do O, São Paulo',
#  'RUA VINTE E DOIS DE AGOSTO, 505, JARDIM BELA VISTA, São Paulo',
#  'RUA CIRILO CORREIA, 168 CASA 0, JARDIM DAMASCENO, São Paulo',
#  'RUA CIRILO CORREIA, 168 CASA 0, JARDIM DAMASCENO, São Paulo',
#  'RUA SANTO ADRIANO, 240, PEDRA BRANCA, São Paulo',
#  'RUA FIRMINOPOLIS, 1260, JD. VISTA ALEGRE, São Paulo',
#  'RUA CAPITAO FIRMINO, 10, LAUZANE, São Paulo',
#  'RUA ANTONIO AMORIM, 126, Jardim Peri, São Paulo',
#  'RUA ALMADA, 33, IMIRIM, São Paulo',
#  'RUA AUGUSTA, 746, Consolacao, São Paulo',
#  'RUA B, 187, Brasilandia, São Paulo',
#  'RUA BALTAZAR DA SILVEIRA, 50a , VILA BONILHA, São Paulo',
#  'AV. Parada Pinto  207 Ap 505, 505, V. N. Cachoeirinha, São Paulo',
#  'AV. Parada Pinto  207 - Ap 603, 603, V; N. Cachoeirinha, São Paulo',
#  'RUA Vicente Lazzari, 281, Brasilandia, São Paulo',
#  'RUA Jose Pedreschi, 290, V. N. Cachoeirinha, São Paulo',
#  'RUA JOSE PEDRESCHI, 290, VILA SOUZA, São Paulo',
#  'AV. PERI RONCHETTI, 175, JARDIM PERI, São Paulo',
#  'RUA MAL.MELLO ARARIGBOIA, 377, VILA SOUZA, São Paulo',
#  'RUA AUGUSTO VIANA DE CASTELO, 216, IMIRIM, São Paulo',
#  'RUA JUAN ARFE, 31, FREGUESIA DO O, São Paulo',
#  'RUA DOS MADRIGAIS, 89, V.N.CACHOEIRINHA, São Paulo',
#  'AV. AV. PARADA PINTO, 1345, VILA NOVA CACHOEIRINHA, São Paulo',
#  'RUA Liestal, 60, Lauzane Paulista, São Paulo',
#  'RUA DR.SALES MALHEIROS, 42, JARDIM PERI, São Paulo',
#  'RUA MINISTRO BARBOSA LIMA, 35, JARDIM  CACHOEIRA, São Paulo',
#  'RUA CACHOEIRA DOS ANTUNES, 55, Jardim Peri, São Paulo',
#  'erro',
#  'erro']

# %%
k = []
j = []
for i in address1:
    params = dict(
        address = i

    )
    
    for x in i:
    
        i = params
    #for z in range(len(i)):
            
        #print(z)
    for y in params: 
    

        base_url = 'https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyARuS0UXjtWXThUyKL9KWfrFqVT7TDsmSI&'
        response = requests.get(base_url, params=params)
        
        

        #data = response.json()['results'][0]['formatted_address']
        #data2 = response.json()['results'][0]['address_components'][-1]['long_name'] 
        #k.append(data)
        #j.append(data2)
        data = response.json()
        if data['status'] == 'OK':
            data1 = data['results'][0]['address_components'][-1]['long_name']
            data2 = data['results'][0]['formatted_address']
        else:  
            k.append('erro')
            j.append('erro')
        #print(data2)
        k.append(data1)
        j.append(data2)
        
dfk = pd.DataFrame(k)
dfj = pd.Series(j)
dfk['Endereco'] = dfj
dfk.rename(columns = {0:'CEP'},inplace = True)
dfk
# Out:
#           CEP                                           Endereco
# 0   02739-000  Av. Itaberaba, 4827 - Itaberaba, São Paulo - S...
# 1   02874-000  R. Ari Carneiro Fernandes, 263 - Jardim dos Fr...
# 2   02844-060  Rua Tiro ao Pombo, 402 - Brasilândia, São Paul...
# 3   02617-000  R. Vinte e Dois de Agosto, 505 - Vila Bela Vis...
# 4   02879-180  Rua Cirilo Correia, 168 - CASA 0 - Jardim Dama...
# 5   02879-180  Rua Cirilo Correia, 168 - CASA 0 - Jardim Dama...
# 6   02634-000  R. Santo Adriano, 240 - Jardim Peri, São Paulo...
# 7   02675-031  R. Firminópolis, 1260 - Jardim Vista Alegre, S...
# 8   02442-030  R. Cap. Firmino, 10 - Lauzane Paulista, São Pa...
# 9   02650-110  R. Antônio Amorim, 126 - Jardim Peri, São Paul...
# 10  02470-140  R. Almada, 33 - Imirim, São Paulo - SP, 02470-...
# 11  01304-001  R. Augusta, 746 - Cerqueira César, São Paulo -...
# 12  02859-150  R. B, 187 - Jardim Vitória Régia (Zona Norte),...
# 13  02931-040  R. Baltazar da Silveira, 50 - Vila Pereira Cer...
# 14  02611-000  Av. Parada Pinto, 207 - Ap 505, 505 - Vila Nov...
# 15  02611-000  Av. Parada Pinto, 207 - Ap 603, 603 - Vila Nov...
# 16  02856-000  Rua Vicente Lazzari, 281 - Jardim Princesa, Sã...
# 17  02881-000  R. José Pedreschi, 290 - Vila Francos, São Pau...
# 18  02881-000  R. José Pedreschi, 290 - Vila Francos, São Pau...
# 19  02633-000  Av. Peri Ronchetti, 175 - Jardim Peri, São Pau...
# 20  02880-060  Rua Marechal Mello Ararigbóia, 377 - Vila Fran...
# 21  02471-020  R. Augusto Viana de Castelo, 216 - Vila Basile...
# 22  02804-080  R. Juan Arfe, 31 - Vila Cruz das Almas, São Pa...
# 23  02614-110  R. Madrigais, 89 - Vila Nova Cachoeirinha, São...
# 24  02611-003  Av. Parada Pinto, 1345 - Vila Nova Cachoeirinh...
# 25  02442-020  R. Liestal, 60 - Lauzane Paulista, São Paulo -...
# 26  02649-030  R. Dr. Sáles Malheiros, 42 - Jardim Peri, São ...
# 27  02764-000  R. Min. Barbosa Lima, 35 - Parque Itaberaba, S...
# 28  02649-000  R. Cachoeira dos Antunes, 55 - Jardim Peri, Sã...
# 29       2169  15450 New Barn Rd STE 101, Hialeah, FL 33014, USA
# 30       2169  15450 New Barn Rd STE 101, Hialeah, FL 33014, USA

# %%
dfk.to_excel('dadoscepFelix.xlsx')
